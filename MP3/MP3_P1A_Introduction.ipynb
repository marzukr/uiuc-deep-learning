# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir("/content/gdrive/My Drive/cs498/assignment3_p1_starterkit")

# If CUDA 10.2 is installed
# !pip install torch==1.5.1 torchvision==0.6.1

# If CUDA 10.1 is installed 
# !pip install torch==1.5.1+cu101 torchvision==0.6.1+cu101 -f https://download.pytorch.org/whl/torch_stable.html

# If CUDA 9.2 is installed
# !pip install torch==1.5.1+cu92 torchvision==0.6.1+cu92 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: torch==1.5.1+cu101 in /usr/local/lib/python3.6/dist-packages (1.5.1+cu101)
# Requirement already satisfied: torchvision==0.6.1+cu101 in /usr/local/lib/python3.6/dist-packages (0.6.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch==1.5.1+cu101) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch==1.5.1+cu101) (0.16.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.6.1+cu101) (7.0.0)

# %%
import shutil 
shutil.copyfile("VOCtrainval_06-Nov-2007.tar", "/content/VOCtrainval_06-Nov-2007.tar")
# !tar -xf "/content/VOCtrainval_06-Nov-2007.tar" -C "/content/" 
shutil.move("/content/VOCdevkit/", "/content/VOCdevkit_2007")

shutil.copyfile("VOCtest_06-Nov-2007.tar", "/content/VOCtest_06-Nov-2007.tar")
# !tar -xf "/content/VOCtest_06-Nov-2007.tar" -C "/content/" 
shutil.move("/content/VOCdevkit/VOC2007", "/content/VOCdevkit_2007/VOC2007test")
# Out:
# '/content/VOCdevkit_2007/VOC2007test'

# %% [markdown]
# # Assignment 3 Part 1A Introduction: Multi-label Image Classification

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from kaggle_submission import output_submission_csv
from classifier import SimpleClassifier, Classifier#, AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Multi-label Classification
# In this assignment, you train a classifier to do multi-label classificaton on the PASCAL VOC 2007 dataset. The dataset has 20 different class which can appear in any given image. Your classifier will predict whether each class appears in an image. This task is slightly different from exclusive multiclass classification like the ImageNet competition where only a single most appropriate class is predicted for an image.
#
# ## Part 1A
# You will use this notebook to warm up with pytorch and the code+dataset that we will use for assignment3.
#
# ### What to do
# In part 1A, You are asked to run below experiments. You don't need to change hyperparameters for this Part 1A's experiments. (the following code provides everything that you will need.)
# 1. to train a simple network (defined in ```classifiers.py```)
# 2. to train the AlexNet (PyTorch built-in)
#     - from scratch
#     - finetuning AlexNet pretrained on ImageNet
#
#
#
# ### What to submit
# We ask you to run the following code and report the results in your homework submission. You may want to leverage this part 1A get yourself familiar with PyTorch.
#
# You will the need the numbers and plots this notebook outputs for reports, but you are not required to submit this notebook as a printed pdf.

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# ### Loading Training Data

# %% [markdown]
# In the following cell we will load the training data and also apply some transforms to the data.

# %%
# Transforms applied to the training data
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize
        ])

# %%
ds_train = VocDataset('/content/VOCdevkit_2007/VOC2007','train',train_transform)

# %% [markdown]
# ### Loading Validation Data

# %% [markdown]
# We will load the test data for the PASCAL VOC 2007 dataset. Do __NOT__ add data augmentation transforms to validation data.

# %%
# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

# %%
ds_val = VocDataset('/content/VOCdevkit_2007/VOC2007','val',test_transform)

# %% [markdown]
# ### Visualizing the Data
#
# PASCAL VOC has bounding box annotations in addition to class labels. Use the following code to visualize some random examples and corresponding annotations from the train set.

# %%
for i in range(5):
    idx = np.random.randint(0, len(ds_train.names)+1)
    _imgpath = os.path.join('/content/VOCdevkit_2007/VOC2007/', 'JPEGImages', ds_train.names[idx]+'.jpg')
    img = Image.open(_imgpath).convert('RGB')
    draw = ImageDraw.Draw(img)
    for j in range(len(ds_train.box_indices[idx])):
        obj = ds_train.box_indices[idx][j]
        draw.rectangle(list(obj), outline=(255,0,0))
        draw.text(list(obj[0:2]), ds_train.classes[ds_train.label_order[idx][j]], fill=(0,255,0))
    plt.figure(figsize = (10,10))
    plt.imshow(np.array(img))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Classification

# %%
# declare what device to use: gpu/cpu
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=50, 
                                               shuffle=True,
                                               num_workers=1)

# %%
val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=50, 
                                               shuffle=True,
                                               num_workers=1)

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels, _) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True, print_total=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels, _) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        if print_total:
            print('mAP: {0:.4f}'.format(mAP))
            print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %%
# plot functions
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()
    
def plot_mAP(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("mAP Plot")
    plt.ylabel("mAP")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %% [markdown]
# ## Training the network
#
# The simple network you are given as is will allow you to reach around 0.15-0.2 mAP. In this project, you will find ways to design a better network. Save plots and final test mAP scores as you will be adding these to the writeup.

# %%
def train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency=5):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
        print("Starting epoch number " + str(epoch))
        train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
        train_losses.append(train_loss)
        print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
        if(epoch%test_frequency==0 or epoch==1):
            mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
            train_mAPs.append(mAP_train)
            mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
            print('Evaluating classifier')
            print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
            val_losses.append(val_loss)
            val_mAPs.append(mAP_val)
    
    return classifier, train_losses, val_losses, train_mAPs, val_mAPs

# %%
classifier = SimpleClassifier().to(device)
# You can can use this function to reload a network you have already saved previously
#classifier.load_state_dict(torch.load('voc_classifier.pth'))

# %%
criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)

# %%
# Training the Classifier
num_epochs = 20
test_frequency = 5

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.5498771071434021
# -------  Class: aeroplane        AP:   0.1244  -------
# -------  Class: bicycle          AP:   0.0501  -------
# -------  Class: bird             AP:   0.1124  -------
# -------  Class: boat             AP:   0.1108  -------
# -------  Class: bottle           AP:   0.0411  -------
# -------  Class: bus              AP:   0.0306  -------
# -------  Class: car              AP:   0.1158  -------
# -------  Class: cat              AP:   0.0781  -------
# -------  Class: chair            AP:   0.1204  -------
# -------  Class: cow              AP:   0.0295  -------
# -------  Class: diningtable      AP:   0.0503  -------
# -------  Class: dog              AP:   0.1103  -------
# -------  Class: horse            AP:   0.0511  -------
# -------  Class: motorbike        AP:   0.0486  -------
# -------  Class: person           AP:   0.3543  -------
# -------  Class: pottedplant      AP:   0.0458  -------
# -------  Class: sheep            AP:   0.0247  -------
# -------  Class: sofa             AP:   0.0860  -------
# -------  Class: train            AP:   0.0361  -------
# -------  Class: tvmonitor        AP:   0.0495  -------
# mAP: 0.0835
# Avg loss: 0.258073639051587
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08349736262716577
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.24789145588874817
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.24272242188453674
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.24573196470737457
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.24206934869289398
# -------  Class: aeroplane        AP:   0.0829  -------
# -------  Class: bicycle          AP:   0.0455  -------
# -------  Class: bird             AP:   0.1059  -------
# -------  Class: boat             AP:   0.0766  -------
# -------  Class: bottle           AP:   0.0455  -------
# -------  Class: bus              AP:   0.0297  -------
# -------  Class: car              AP:   0.1144  -------
# -------  Class: cat              AP:   0.1040  -------
# -------  Class: chair            AP:   0.1387  -------
# -------  Class: cow              AP:   0.0305  -------
# -------  Class: diningtable      AP:   0.0575  -------
# -------  Class: dog              AP:   0.1289  -------
# -------  Class: horse            AP:   0.0493  -------
# -------  Class: motorbike        AP:   0.0428  -------
# -------  Class: person           AP:   0.4650  -------
# -------  Class: pottedplant      AP:   0.0474  -------
# -------  Class: sheep            AP:   0.0258  -------
# -------  Class: sofa             AP:   0.1126  -------
# -------  Class: train            AP:   0.0358  -------
# -------  Class: tvmonitor        AP:   0.0542  -------
# mAP: 0.0896
# Avg loss: 0.23741666300624026
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.08964401822712578
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.24319526553153992
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.24230508506298065
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.23666061460971832
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.23734627664089203
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.2352789044380188
# -------  Class: aeroplane        AP:   0.1559  -------
# -------  Class: bicycle          AP:   0.0484  -------
# -------  Class: bird             AP:   0.1104  -------
# -------  Class: boat             AP:   0.1030  -------
# -------  Class: bottle           AP:   0.0563  -------
# -------  Class: bus              AP:   0.0432  -------
# -------  Class: car              AP:   0.1435  -------
# -------  Class: cat              AP:   0.1213  -------
# -------  Class: chair            AP:   0.1754  -------
# -------  Class: cow              AP:   0.0347  -------
# -------  Class: diningtable      AP:   0.0773  -------
# -------  Class: dog              AP:   0.1336  -------
# -------  Class: horse            AP:   0.0547  -------
# -------  Class: motorbike        AP:   0.0431  -------
# -------  Class: person           AP:   0.4819  -------
# -------  Class: pottedplant      AP:   0.0502  -------
# -------  Class: sheep            AP:   0.0300  -------
# -------  Class: sofa             AP:   0.1581  -------
# -------  Class: train            AP:   0.0522  -------
# -------  Class: tvmonitor        AP:   0.0602  -------
# mAP: 0.1067
# Avg loss: 0.23100338525631847
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.10667098816128621
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.23329783976078033
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.23294629156589508
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.23165932297706604
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.2280855029821396
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.22587460279464722
# -------  Class: aeroplane        AP:   0.3003  -------
# -------  Class: bicycle          AP:   0.0563  -------
# -------  Class: bird             AP:   0.1162  -------
# -------  Class: boat             AP:   0.1695  -------
# -------  Class: bottle           AP:   0.0792  -------
# -------  Class: bus              AP:   0.0604  -------
# -------  Class: car              AP:   0.1806  -------
# -------  Class: cat              AP:   0.1401  -------
# -------  Class: chair            AP:   0.2117  -------
# -------  Class: cow              AP:   0.0447  -------
# -------  Class: diningtable      AP:   0.1357  -------
# -------  Class: dog              AP:   0.1531  -------
# -------  Class: horse            AP:   0.0840  -------
# -------  Class: motorbike        AP:   0.0487  -------
# -------  Class: person           AP:   0.4830  -------
# -------  Class: pottedplant      AP:   0.0602  -------
# -------  Class: sheep            AP:   0.0309  -------
# -------  Class: sofa             AP:   0.1865  -------
# -------  Class: train            AP:   0.1116  -------
# -------  Class: tvmonitor        AP:   0.0779  -------
# mAP: 0.1365
# Avg loss: 0.22579832813319037
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.13653497632964412
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.22434717416763306
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.22156578302383423
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.2202329933643341
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.2204197347164154
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.21702243387699127
# -------  Class: aeroplane        AP:   0.3458  -------
# -------  Class: bicycle          AP:   0.0638  -------
# -------  Class: bird             AP:   0.1054  -------
# -------  Class: boat             AP:   0.2145  -------
# -------  Class: bottle           AP:   0.0881  -------
# -------  Class: bus              AP:   0.0783  -------
# -------  Class: car              AP:   0.2103  -------
# -------  Class: cat              AP:   0.1647  -------
# -------  Class: chair            AP:   0.2405  -------
# -------  Class: cow              AP:   0.0504  -------
# -------  Class: diningtable      AP:   0.1657  -------
# -------  Class: dog              AP:   0.1577  -------
# -------  Class: horse            AP:   0.1225  -------
# -------  Class: motorbike        AP:   0.0664  -------
# -------  Class: person           AP:   0.5102  -------
# -------  Class: pottedplant      AP:   0.0844  -------
# -------  Class: sheep            AP:   0.0410  -------
# -------  Class: sofa             AP:   0.2120  -------
# -------  Class: train            AP:   0.1530  -------
# -------  Class: tvmonitor        AP:   0.1145  -------
# mAP: 0.1595
# Avg loss: 0.22113959987958273
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.15946259568356722

# %%
# Compare train and validation metrics
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
# Save the clssifier network
# Suggestion: you can save checkpoints of your network during training and reload them later
torch.save(classifier.state_dict(), './voc_simple_classifier.pth')

# %% [markdown]
# # Evaluate on test set

# %%
ds_test = VocDataset('/content/VOCdevkit_2007/VOC2007test/','test', test_transform)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=50, 
                                               shuffle=False,
                                               num_workers=1)

# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
# Out:
# -------  Class: aeroplane        AP:   0.3433  -------
# -------  Class: bicycle          AP:   0.0616  -------
# -------  Class: bird             AP:   0.1093  -------
# -------  Class: boat             AP:   0.1720  -------
# -------  Class: bottle           AP:   0.0849  -------
# -------  Class: bus              AP:   0.0613  -------
# -------  Class: car              AP:   0.2390  -------
# -------  Class: cat              AP:   0.1139  -------
# -------  Class: chair            AP:   0.2373  -------
# -------  Class: cow              AP:   0.0536  -------
# -------  Class: diningtable      AP:   0.1228  -------
# -------  Class: dog              AP:   0.1616  -------
# -------  Class: horse            AP:   0.1243  -------
# -------  Class: motorbike        AP:   0.0721  -------
# -------  Class: person           AP:   0.5233  -------
# -------  Class: pottedplant      AP:   0.0690  -------
# -------  Class: sheep            AP:   0.0595  -------
# -------  Class: sofa             AP:   0.2031  -------
# -------  Class: train            AP:   0.1669  -------
# -------  Class: tvmonitor        AP:   0.0987  -------
# mAP: 0.1539
# Avg loss: 0.2173609133064747

# %%
output_submission_csv('my_solution.csv', test_aps)

# %% [markdown]
# # AlexNet Baselines (From Scratch)

# %% [markdown]
# AlexNet was one of the earliest deep learning models to have success in classification. In this section we will be running classification with AlexNet as a baseline. Furthermore, we will run an ImageNet-pretrained AlexNet to observe the impact of well-trained features. Save plots and final test mAP scores as you will be adding these to the writeup.

# %% [markdown]
# ## Running AlexNet
#
# In this section, we train AlexNet from scratch using the same hyperparameters as our previous experiment.

# %%
num_epochs = 20
test_frequency = 5

# Change classifier to AlexNet
classifier = torchvision.models.alexnet(pretrained=False)
classifier.classifier._modules['6'] = nn.Linear(4096, 21)   
classifier = classifier.to(device)

criterion = nn.MultiLabelSoftMarginLoss()

optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)

# %%
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.6061028242111206
# -------  Class: aeroplane        AP:   0.1378  -------
# -------  Class: bicycle          AP:   0.0446  -------
# -------  Class: bird             AP:   0.1080  -------
# -------  Class: boat             AP:   0.1221  -------
# -------  Class: bottle           AP:   0.0387  -------
# -------  Class: bus              AP:   0.0296  -------
# -------  Class: car              AP:   0.1110  -------
# -------  Class: cat              AP:   0.0900  -------
# -------  Class: chair            AP:   0.1093  -------
# -------  Class: cow              AP:   0.0351  -------
# -------  Class: diningtable      AP:   0.0473  -------
# -------  Class: dog              AP:   0.1097  -------
# -------  Class: horse            AP:   0.0465  -------
# -------  Class: motorbike        AP:   0.0368  -------
# -------  Class: person           AP:   0.3323  -------
# -------  Class: pottedplant      AP:   0.0421  -------
# -------  Class: sheep            AP:   0.0355  -------
# -------  Class: sofa             AP:   0.0860  -------
# -------  Class: train            AP:   0.0400  -------
# -------  Class: tvmonitor        AP:   0.0474  -------
# mAP: 0.0825
# Avg loss: 0.2610304083894281
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08248647361533866
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.26771554350852966
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.24444139003753662
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.24472233653068542
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.24604947865009308
# -------  Class: aeroplane        AP:   0.0926  -------
# -------  Class: bicycle          AP:   0.0440  -------
# -------  Class: bird             AP:   0.1124  -------
# -------  Class: boat             AP:   0.0978  -------
# -------  Class: bottle           AP:   0.0416  -------
# -------  Class: bus              AP:   0.0286  -------
# -------  Class: car              AP:   0.1101  -------
# -------  Class: cat              AP:   0.0969  -------
# -------  Class: chair            AP:   0.1194  -------
# -------  Class: cow              AP:   0.0355  -------
# -------  Class: diningtable      AP:   0.0535  -------
# -------  Class: dog              AP:   0.1188  -------
# -------  Class: horse            AP:   0.0478  -------
# -------  Class: motorbike        AP:   0.0366  -------
# -------  Class: person           AP:   0.3559  -------
# -------  Class: pottedplant      AP:   0.0455  -------
# -------  Class: sheep            AP:   0.0443  -------
# -------  Class: sofa             AP:   0.0971  -------
# -------  Class: train            AP:   0.0403  -------
# -------  Class: tvmonitor        AP:   0.0482  -------
# mAP: 0.0833
# Avg loss: 0.2437694814859652
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.08333761563127422
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.24328278005123138
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.23893046379089355
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.2425776571035385
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.2400193065404892
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.24119512736797333
# -------  Class: aeroplane        AP:   0.0813  -------
# -------  Class: bicycle          AP:   0.0474  -------
# -------  Class: bird             AP:   0.1197  -------
# -------  Class: boat             AP:   0.0908  -------
# -------  Class: bottle           AP:   0.0409  -------
# -------  Class: bus              AP:   0.0294  -------
# -------  Class: car              AP:   0.1150  -------
# -------  Class: cat              AP:   0.0927  -------
# -------  Class: chair            AP:   0.1218  -------
# -------  Class: cow              AP:   0.0361  -------
# -------  Class: diningtable      AP:   0.0541  -------
# -------  Class: dog              AP:   0.1203  -------
# -------  Class: horse            AP:   0.0506  -------
# -------  Class: motorbike        AP:   0.0394  -------
# -------  Class: person           AP:   0.4589  -------
# -------  Class: pottedplant      AP:   0.0488  -------
# -------  Class: sheep            AP:   0.0471  -------
# -------  Class: sofa             AP:   0.0943  -------
# -------  Class: train            AP:   0.0416  -------
# -------  Class: tvmonitor        AP:   0.0492  -------
# mAP: 0.0890
# Avg loss: 0.23645850460903317
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.08895864345975542
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.24038323760032654
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.2399827241897583
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.23737163841724396
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.239751398563385
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.23825688660144806
# -------  Class: aeroplane        AP:   0.0750  -------
# -------  Class: bicycle          AP:   0.0506  -------
# -------  Class: bird             AP:   0.1273  -------
# -------  Class: boat             AP:   0.0846  -------
# -------  Class: bottle           AP:   0.0412  -------
# -------  Class: bus              AP:   0.0303  -------
# -------  Class: car              AP:   0.1232  -------
# -------  Class: cat              AP:   0.0895  -------
# -------  Class: chair            AP:   0.1272  -------
# -------  Class: cow              AP:   0.0365  -------
# -------  Class: diningtable      AP:   0.0562  -------
# -------  Class: dog              AP:   0.1180  -------
# -------  Class: horse            AP:   0.0537  -------
# -------  Class: motorbike        AP:   0.0433  -------
# -------  Class: person           AP:   0.4475  -------
# -------  Class: pottedplant      AP:   0.0524  -------
# -------  Class: sheep            AP:   0.0479  -------
# -------  Class: sofa             AP:   0.0933  -------
# -------  Class: train            AP:   0.0434  -------
# -------  Class: tvmonitor        AP:   0.0497  -------
# mAP: 0.0895
# Avg loss: 0.2361204013520596
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.08952914952313001
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.23986375331878662
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.23947663605213165
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.23820072412490845
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.23835888504981995
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.23660629987716675
# -------  Class: aeroplane        AP:   0.0767  -------
# -------  Class: bicycle          AP:   0.0513  -------
# -------  Class: bird             AP:   0.1294  -------
# -------  Class: boat             AP:   0.0755  -------
# -------  Class: bottle           AP:   0.0483  -------
# -------  Class: bus              AP:   0.0307  -------
# -------  Class: car              AP:   0.1382  -------
# -------  Class: cat              AP:   0.0930  -------
# -------  Class: chair            AP:   0.1465  -------
# -------  Class: cow              AP:   0.0367  -------
# -------  Class: diningtable      AP:   0.0687  -------
# -------  Class: dog              AP:   0.1188  -------
# -------  Class: horse            AP:   0.0571  -------
# -------  Class: motorbike        AP:   0.0463  -------
# -------  Class: person           AP:   0.4732  -------
# -------  Class: pottedplant      AP:   0.0593  -------
# -------  Class: sheep            AP:   0.0482  -------
# -------  Class: sofa             AP:   0.1027  -------
# -------  Class: train            AP:   0.0486  -------
# -------  Class: tvmonitor        AP:   0.0499  -------
# mAP: 0.0950
# Avg loss: 0.23373825789666644
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.09495684238088622

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print("Test mAP: ", mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.0621  -------
# -------  Class: bicycle          AP:   0.0528  -------
# -------  Class: bird             AP:   0.0981  -------
# -------  Class: boat             AP:   0.0534  -------
# -------  Class: bottle           AP:   0.0496  -------
# -------  Class: bus              AP:   0.0296  -------
# -------  Class: car              AP:   0.1397  -------
# -------  Class: cat              AP:   0.0929  -------
# -------  Class: chair            AP:   0.1358  -------
# -------  Class: cow              AP:   0.0402  -------
# -------  Class: diningtable      AP:   0.0556  -------
# -------  Class: dog              AP:   0.1244  -------
# -------  Class: horse            AP:   0.0561  -------
# -------  Class: motorbike        AP:   0.0412  -------
# -------  Class: person           AP:   0.4751  -------
# -------  Class: pottedplant      AP:   0.0526  -------
# -------  Class: sheep            AP:   0.0553  -------
# -------  Class: sofa             AP:   0.1068  -------
# -------  Class: train            AP:   0.0496  -------
# -------  Class: tvmonitor        AP:   0.0509  -------
# mAP: 0.0911
# Avg loss: 0.2303096807003021
# Test mAP:  0.09107626977221836

# %% [markdown]
# You should notice somewhat poor performance. You could try running AlexNet with an Adam optimizer instead with learning rate 1e-4 to see if that makes a difference. This experiment is not required for the writeup, but it may show you the importance of a good learning rate and optimizer.

# %% [markdown]
# ## Pretrained AlexNet

# %% [markdown]
# Here we look at the impact of pretrained features. This model's weights were trained on ImageNet, which is a much larger dataset. How do pretrained features perform on VOC? Why do you think there is such a large difference in performance?

# %%
num_epochs = 20
test_frequency = 5

# Load Pretrained AlexNet
classifier = torchvision.models.alexnet(pretrained=True)
classifier.classifier._modules['6'] = nn.Linear(4096, 21)   
classifier = classifier.to(device)
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/checkpoints/alexnet-owt-4df8aa71.pth
# HBox(children=(FloatProgress(value=0.0, max=244418560.0), HTML(value='')))

# %%
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.22697557508945465
# -------  Class: aeroplane        AP:   0.6930  -------
# -------  Class: bicycle          AP:   0.5443  -------
# -------  Class: bird             AP:   0.8119  -------
# -------  Class: boat             AP:   0.5992  -------
# -------  Class: bottle           AP:   0.2419  -------
# -------  Class: bus              AP:   0.4984  -------
# -------  Class: car              AP:   0.7575  -------
# -------  Class: cat              AP:   0.6850  -------
# -------  Class: chair            AP:   0.6057  -------
# -------  Class: cow              AP:   0.2928  -------
# -------  Class: diningtable      AP:   0.5265  -------
# -------  Class: dog              AP:   0.6053  -------
# -------  Class: horse            AP:   0.6370  -------
# -------  Class: motorbike        AP:   0.6782  -------
# -------  Class: person           AP:   0.8994  -------
# -------  Class: pottedplant      AP:   0.3615  -------
# -------  Class: sheep            AP:   0.2005  -------
# -------  Class: sofa             AP:   0.4539  -------
# -------  Class: train            AP:   0.7381  -------
# -------  Class: tvmonitor        AP:   0.4736  -------
# mAP: 0.5652
# Avg loss: 0.14202004641878838
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.565181169334526
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.12259932607412338
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.10390115529298782
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.09147246181964874
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.08244539797306061
# -------  Class: aeroplane        AP:   0.8383  -------
# -------  Class: bicycle          AP:   0.7102  -------
# -------  Class: bird             AP:   0.8674  -------
# -------  Class: boat             AP:   0.7432  -------
# -------  Class: bottle           AP:   0.3337  -------
# -------  Class: bus              AP:   0.6216  -------
# -------  Class: car              AP:   0.8245  -------
# -------  Class: cat              AP:   0.7813  -------
# -------  Class: chair            AP:   0.6135  -------
# -------  Class: cow              AP:   0.4817  -------
# -------  Class: diningtable      AP:   0.6243  -------
# -------  Class: dog              AP:   0.7247  -------
# -------  Class: horse            AP:   0.7422  -------
# -------  Class: motorbike        AP:   0.7895  -------
# -------  Class: person           AP:   0.9092  -------
# -------  Class: pottedplant      AP:   0.4809  -------
# -------  Class: sheep            AP:   0.6295  -------
# -------  Class: sofa             AP:   0.5677  -------
# -------  Class: train            AP:   0.8878  -------
# -------  Class: tvmonitor        AP:   0.6445  -------
# mAP: 0.6908
# Avg loss: 0.12000583755035027
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.6907855114906797
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.07387057691812515
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.0653601586818695
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.07840641587972641
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.05262386426329613
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.045131731778383255
# -------  Class: aeroplane        AP:   0.8357  -------
# -------  Class: bicycle          AP:   0.7032  -------
# -------  Class: bird             AP:   0.8632  -------
# -------  Class: boat             AP:   0.7072  -------
# -------  Class: bottle           AP:   0.3861  -------
# -------  Class: bus              AP:   0.6139  -------
# -------  Class: car              AP:   0.8248  -------
# -------  Class: cat              AP:   0.7933  -------
# -------  Class: chair            AP:   0.6210  -------
# -------  Class: cow              AP:   0.5221  -------
# -------  Class: diningtable      AP:   0.6207  -------
# -------  Class: dog              AP:   0.6952  -------
# -------  Class: horse            AP:   0.7675  -------
# -------  Class: motorbike        AP:   0.7860  -------
# -------  Class: person           AP:   0.9064  -------
# -------  Class: pottedplant      AP:   0.3932  -------
# -------  Class: sheep            AP:   0.6243  -------
# -------  Class: sofa             AP:   0.5538  -------
# -------  Class: train            AP:   0.8903  -------
# -------  Class: tvmonitor        AP:   0.6395  -------
# mAP: 0.6874
# Avg loss: 0.1319421589666722
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.6873667529063573
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.03908686339855194
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.034840118139982224
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.02951877750456333
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.025007396936416626
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.022269506007432938
# -------  Class: aeroplane        AP:   0.8573  -------
# -------  Class: bicycle          AP:   0.6864  -------
# -------  Class: bird             AP:   0.8547  -------
# -------  Class: boat             AP:   0.7098  -------
# -------  Class: bottle           AP:   0.3530  -------
# -------  Class: bus              AP:   0.5987  -------
# -------  Class: car              AP:   0.8211  -------
# -------  Class: cat              AP:   0.7901  -------
# -------  Class: chair            AP:   0.5871  -------
# -------  Class: cow              AP:   0.5251  -------
# -------  Class: diningtable      AP:   0.6006  -------
# -------  Class: dog              AP:   0.6682  -------
# -------  Class: horse            AP:   0.7740  -------
# -------  Class: motorbike        AP:   0.7927  -------
# -------  Class: person           AP:   0.9059  -------
# -------  Class: pottedplant      AP:   0.4319  -------
# -------  Class: sheep            AP:   0.6085  -------
# -------  Class: sofa             AP:   0.5302  -------
# -------  Class: train            AP:   0.8861  -------
# -------  Class: tvmonitor        AP:   0.6426  -------
# mAP: 0.6812
# Avg loss: 0.15808554738759995
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.6812030241591296
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.018103089183568954
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.01682405360043049
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.0148205840960145
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.014594529755413532
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.012329425662755966
# -------  Class: aeroplane        AP:   0.8496  -------
# -------  Class: bicycle          AP:   0.6928  -------
# -------  Class: bird             AP:   0.8566  -------
# -------  Class: boat             AP:   0.7049  -------
# -------  Class: bottle           AP:   0.3606  -------
# -------  Class: bus              AP:   0.6030  -------
# -------  Class: car              AP:   0.8103  -------
# -------  Class: cat              AP:   0.7756  -------
# -------  Class: chair            AP:   0.5952  -------
# -------  Class: cow              AP:   0.5005  -------
# -------  Class: diningtable      AP:   0.6125  -------
# -------  Class: dog              AP:   0.6880  -------
# -------  Class: horse            AP:   0.7596  -------
# -------  Class: motorbike        AP:   0.7726  -------
# -------  Class: person           AP:   0.9059  -------
# -------  Class: pottedplant      AP:   0.4077  -------
# -------  Class: sheep            AP:   0.6048  -------
# -------  Class: sofa             AP:   0.5115  -------
# -------  Class: train            AP:   0.8871  -------
# -------  Class: tvmonitor        AP:   0.5985  -------
# mAP: 0.6749
# Avg loss: 0.19150856020403842
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.6748693422084252

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print("Test mAP: ", mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.8440  -------
# -------  Class: bicycle          AP:   0.7551  -------
# -------  Class: bird             AP:   0.8268  -------
# -------  Class: boat             AP:   0.7921  -------
# -------  Class: bottle           AP:   0.3174  -------
# -------  Class: bus              AP:   0.6323  -------
# -------  Class: car              AP:   0.8248  -------
# -------  Class: cat              AP:   0.7827  -------
# -------  Class: chair            AP:   0.5807  -------
# -------  Class: cow              AP:   0.5114  -------
# -------  Class: diningtable      AP:   0.6214  -------
# -------  Class: dog              AP:   0.7113  -------
# -------  Class: horse            AP:   0.8216  -------
# -------  Class: motorbike        AP:   0.7493  -------
# -------  Class: person           AP:   0.9166  -------
# -------  Class: pottedplant      AP:   0.4473  -------
# -------  Class: sheep            AP:   0.6877  -------
# -------  Class: sofa             AP:   0.4999  -------
# -------  Class: train            AP:   0.8734  -------
# -------  Class: tvmonitor        AP:   0.6072  -------
# mAP: 0.6901
# Avg loss: 0.18634538821876048
# Test mAP:  0.6901433775174732
