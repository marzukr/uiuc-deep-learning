# %% [markdown]
# # Assignment 3 Part 1: Developing Your Own Classifier

# %%
# !nvcc --version

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')
# import os
# os.chdir("/content/gdrive/My Drive/cs498/assignment3_p1_starterkit")

# If CUDA 10.2 is installed
# !pip install torch==1.5.1 torchvision==0.6.1

# If CUDA 10.1 is installed 
# !pip install torch==1.5.1+cu101 torchvision==0.6.1+cu101 -f https://download.pytorch.org/whl/torch_stable.html

# If CUDA 9.2 is installed
# !pip install torch==1.5.1+cu92 torchvision==0.6.1+cu92 -f https://download.pytorch.org/whl/torch_stable.html

# %%
# import shutil 
# shutil.copyfile("VOCtrainval_06-Nov-2007.tar", "/content/VOCtrainval_06-Nov-2007.tar")
# !tar -xf "/content/VOCtrainval_06-Nov-2007.tar" -C "/content/" 
# shutil.move("/content/VOCdevkit/", "/content/VOCdevkit_2007")

# shutil.copyfile("VOCtest_06-Nov-2007.tar", "/content/VOCtest_06-Nov-2007.tar")
# !tar -xf "/content/VOCtest_06-Nov-2007.tar" -C "/content/" 
# shutil.move("/content/VOCdevkit/VOC2007", "/content/VOCdevkit_2007/VOC2007test")

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from kaggle_submission import output_submission_csv
from classifier import SimpleClassifier, Classifier#, AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Part 1B: Design your own network
#
# In this notebook, your task is to create and train your own model for multi-label classification on VOC Pascal.
#
# ## What to do
# 1. You will make change on network architecture in ```classifier.py```.
# 2. You may also want to change other hyperparameters to assist your training to get a better performances. Hints will be given in the below instructions.
#
# ## What to submit
# Check the submission template for details what to submit.

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels, _) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True, print_total=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels, _) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        if print_total:
            print('mAP: {0:.4f}'.format(mAP))
            print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %%
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()
    
def plot_mAP(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("mAP Plot")
    plt.ylabel("mAP")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %%
def train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency=5):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
        print("Starting epoch number " + str(epoch))
        train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
        train_losses.append(train_loss)
        print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
        if(epoch%test_frequency==0 or epoch==1):
            mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
            train_mAPs.append(mAP_train)
            mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
            print('Evaluating classifier')
            print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
            val_losses.append(val_loss)
            val_mAPs.append(mAP_val)
#             torch.save(classifier.state_dict(), './voc_my_best_classifier_{}.pth'.format(epoch))
    
    return classifier, train_losses, val_losses, train_mAPs, val_mAPs

# %% [markdown]
# # Developing Your Own Model

# %% [markdown]
# ### Goal
# To meet the benchmark for this assignment you will need to improve the network. Note you should have noticed pretrained Alenxt performs really well, but training Alexnet from scratch performs much worse. We hope you can design a better architecture over both the simple classifier and AlexNet to train from scratch.
#
# ### How to start
# You may take inspiration from other published architectures and architectures discussed in lecture. However, you are NOT allowed to use predefined models (e.g. models from torchvision) or use pretrained weights. Training must be done from scratch with your own custom model.
#
# #### Some hints
# There are a variety of different approaches you should try to improve performance from the simple classifier:
#
# * Network architecture changes
#     * Number of layers: try adding layers to make your network deeper
#     * Batch normalization: adding batch norm between layers will likely give you a significant performance increase
#     * Residual connections: as you increase the depth of your network, you will find that having residual connections like those in ResNet architectures will be helpful
# * Optimizer: Instead of plain SGD, you may want to add a learning rate schedule, add momentum, or use one of the other optimizers you have learned about like Adam. Check the `torch.optim` package for other optimizers
# * Data augmentation: You should use the `torchvision.transforms` module to try adding random resized crops and horizontal flips of the input data. Check `transforms.RandomResizedCrop` and `transforms.RandomHorizontalFlip` for this. Feel free to apply more [transforms](https://pytorch.org/docs/stable/torchvision/transforms.html) for data augmentation which can lead to better performance.
# * Epochs: Once you have found a generally good hyperparameter setting try training for more epochs
# * Loss function: You might want to add weighting to the `MultiLabelSoftMarginLoss` for classes that are less well represented or experiment with a different loss function
#
#
#
# #### Note
# We will soon be providing some initial expectations of mAP values as a function of epoch so you can get an early idea whether your implementation works without waiting a long time for training to converge.
#
# ### What to submit
# Submit your best model to Kaggle and save all plots for the writeup.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.ColorJitter(0.01,0.01,0.01,0.01),
            transforms.RandomResizedCrop(227),
            transforms.ToTensor(),
            normalize
        ])

test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

ds_train = VocDataset('VOCdevkit_2007/VOC2007/','train',train_transform)
ds_val = VocDataset('VOCdevkit_2007/VOC2007/','val',test_transform)
ds_test = VocDataset('VOCdevkit_2007/VOC2007test/','test', test_transform)

# %%
num_epochs = 100
test_frequency = 5
batch_size = 64

train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=batch_size, 
                                               shuffle=False,
                                               num_workers=1)

# %%
# TODO: Run your own classifier here
classifier = Classifier().to(device)

criterion = nn.MultiLabelSoftMarginLoss()
# optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)
optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4, weight_decay=1e-5)

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.4072509706020355
# -------  Class: aeroplane        AP:   0.0345  -------
# -------  Class: bicycle          AP:   0.1100  -------
# -------  Class: bird             AP:   0.0733  -------
# -------  Class: boat             AP:   0.0332  -------
# -------  Class: bottle           AP:   0.0622  -------
# -------  Class: bus              AP:   0.0679  -------
# -------  Class: car              AP:   0.2195  -------
# -------  Class: cat              AP:   0.0548  -------
# -------  Class: chair            AP:   0.1553  -------
# -------  Class: cow              AP:   0.0390  -------
# -------  Class: diningtable      AP:   0.0628  -------
# -------  Class: dog              AP:   0.0703  -------
# -------  Class: horse            AP:   0.0864  -------
# -------  Class: motorbike        AP:   0.1160  -------
# -------  Class: person           AP:   0.5475  -------
# -------  Class: pottedplant      AP:   0.0890  -------
# -------  Class: sheep            AP:   0.0211  -------
# -------  Class: sofa             AP:   0.0659  -------
# -------  Class: train            AP:   0.0793  -------
# -------  Class: tvmonitor        AP:   0.0578  -------
# mAP: 0.1023
# Avg loss: 0.2593559805303812
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.10228701664499402
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.23487277328968048
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.22815851867198944
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.2217334806919098
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.21870242059230804
# -------  Class: aeroplane        AP:   0.4107  -------
# -------  Class: bicycle          AP:   0.1115  -------
# -------  Class: bird             AP:   0.1776  -------
# -------  Class: boat             AP:   0.2146  -------
# -------  Class: bottle           AP:   0.1063  -------
# -------  Class: bus              AP:   0.0867  -------
# -------  Class: car              AP:   0.4074  -------
# -------  Class: cat              AP:   0.2226  -------
# -------  Class: chair            AP:   0.2785  -------
# -------  Class: cow              AP:   0.0513  -------
# -------  Class: diningtable      AP:   0.1857  -------
# -------  Class: dog              AP:   0.1848  -------
# -------  Class: horse            AP:   0.2864  -------
# -------  Class: motorbike        AP:   0.1800  -------
# -------  Class: person           AP:   0.6118  -------
# -------  Class: pottedplant      AP:   0.1250  -------
# -------  Class: sheep            AP:   0.1204  -------
# -------  Class: sofa             AP:   0.1956  -------
# -------  Class: train            AP:   0.1551  -------
# -------  Class: tvmonitor        AP:   0.1048  -------
# mAP: 0.2108
# Avg loss: 0.21119973249733448
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.21082883306456895
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.21280935406684875
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.21298812329769135
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.2095678299665451
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.20650768280029297
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.20581260323524475
# -------  Class: aeroplane        AP:   0.4459  -------
# -------  Class: bicycle          AP:   0.2450  -------
# -------  Class: bird             AP:   0.1813  -------
# -------  Class: boat             AP:   0.2774  -------
# -------  Class: bottle           AP:   0.1138  -------
# -------  Class: bus              AP:   0.1735  -------
# -------  Class: car              AP:   0.4784  -------
# -------  Class: cat              AP:   0.2826  -------
# -------  Class: chair            AP:   0.3293  -------
# -------  Class: cow              AP:   0.0767  -------
# -------  Class: diningtable      AP:   0.2204  -------
# -------  Class: dog              AP:   0.2530  -------
# -------  Class: horse            AP:   0.3155  -------
# -------  Class: motorbike        AP:   0.2440  -------
# -------  Class: person           AP:   0.6859  -------
# -------  Class: pottedplant      AP:   0.1467  -------
# -------  Class: sheep            AP:   0.1526  -------
# -------  Class: sofa             AP:   0.2225  -------
# -------  Class: train            AP:   0.2159  -------
# -------  Class: tvmonitor        AP:   0.1414  -------
# mAP: 0.2601
# Avg loss: 0.19946321323513985
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.260078200200862
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.20212173461914062
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.20109663903713226
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.1960650235414505
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.1939825415611267
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.19533532857894897
# -------  Class: aeroplane        AP:   0.4212  -------
# -------  Class: bicycle          AP:   0.1497  -------
# -------  Class: bird             AP:   0.1581  -------
# -------  Class: boat             AP:   0.2976  -------
# -------  Class: bottle           AP:   0.1093  -------
# -------  Class: bus              AP:   0.1446  -------
# -------  Class: car              AP:   0.4764  -------
# -------  Class: cat              AP:   0.3219  -------
# -------  Class: chair            AP:   0.3713  -------
# -------  Class: cow              AP:   0.0809  -------
# -------  Class: diningtable      AP:   0.1858  -------
# -------  Class: dog              AP:   0.2750  -------
# -------  Class: horse            AP:   0.3534  -------
# -------  Class: motorbike        AP:   0.2806  -------
# -------  Class: person           AP:   0.6778  -------
# -------  Class: pottedplant      AP:   0.1304  -------
# -------  Class: sheep            AP:   0.1550  -------
# -------  Class: sofa             AP:   0.2016  -------
# -------  Class: train            AP:   0.2783  -------
# -------  Class: tvmonitor        AP:   0.2150  -------
# mAP: 0.2642
# Avg loss: 0.20093929804861546
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.2641886519512509
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.19390319287776947
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.19298337399959564
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.19128532707691193
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.18913616240024567
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.1883041113615036
# -------  Class: aeroplane        AP:   0.4764  -------
# -------  Class: bicycle          AP:   0.2640  -------
# -------  Class: bird             AP:   0.1755  -------
# -------  Class: boat             AP:   0.3322  -------
# -------  Class: bottle           AP:   0.1051  -------
# -------  Class: bus              AP:   0.1885  -------
# -------  Class: car              AP:   0.5533  -------
# -------  Class: cat              AP:   0.3307  -------
# -------  Class: chair            AP:   0.3917  -------
# -------  Class: cow              AP:   0.0988  -------
# -------  Class: diningtable      AP:   0.2507  -------
# -------  Class: dog              AP:   0.2581  -------
# -------  Class: horse            AP:   0.4164  -------
# -------  Class: motorbike        AP:   0.2838  -------
# -------  Class: person           AP:   0.7192  -------
# -------  Class: pottedplant      AP:   0.1540  -------
# -------  Class: sheep            AP:   0.1841  -------
# -------  Class: sofa             AP:   0.2426  -------
# -------  Class: train            AP:   0.3960  -------
# -------  Class: tvmonitor        AP:   0.2087  -------
# mAP: 0.3015
# Avg loss: 0.20199481174349784
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.3015021395412836
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.18695878982543945
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.18535274267196655
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.18365883827209473
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.18341539800167084
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.18199646472930908
# -------  Class: aeroplane        AP:   0.4839  -------
# -------  Class: bicycle          AP:   0.2382  -------
# -------  Class: bird             AP:   0.2232  -------
# -------  Class: boat             AP:   0.3734  -------
# -------  Class: bottle           AP:   0.1175  -------
# -------  Class: bus              AP:   0.1551  -------
# -------  Class: car              AP:   0.5258  -------
# -------  Class: cat              AP:   0.3181  -------
# -------  Class: chair            AP:   0.3755  -------
# -------  Class: cow              AP:   0.0997  -------
# -------  Class: diningtable      AP:   0.2082  -------
# -------  Class: dog              AP:   0.2857  -------
# -------  Class: horse            AP:   0.4680  -------
# -------  Class: motorbike        AP:   0.1970  -------
# -------  Class: person           AP:   0.7403  -------
# -------  Class: pottedplant      AP:   0.1539  -------
# -------  Class: sheep            AP:   0.1668  -------
# -------  Class: sofa             AP:   0.2321  -------
# -------  Class: train            AP:   0.3606  -------
# -------  Class: tvmonitor        AP:   0.2152  -------
# mAP: 0.2969
# Avg loss: 0.19743526242673398
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 25 is 0.29690752748140004
# Starting epoch number 26
# Loss for Training on Epoch 26 is 0.18059039115905762
# Starting epoch number 27
# Loss for Training on Epoch 27 is 0.1780603975057602
# Starting epoch number 28
# Loss for Training on Epoch 28 is 0.17701761424541473
# Starting epoch number 29
# Loss for Training on Epoch 29 is 0.1770806759595871
# Starting epoch number 30
# Loss for Training on Epoch 30 is 0.17597226798534393
# -------  Class: aeroplane        AP:   0.4948  -------
# -------  Class: bicycle          AP:   0.2194  -------
# -------  Class: bird             AP:   0.2415  -------
# -------  Class: boat             AP:   0.3772  -------
# -------  Class: bottle           AP:   0.1517  -------
# -------  Class: bus              AP:   0.1890  -------
# -------  Class: car              AP:   0.5709  -------
# -------  Class: cat              AP:   0.3538  -------
# -------  Class: chair            AP:   0.4271  -------
# -------  Class: cow              AP:   0.1343  -------
# -------  Class: diningtable      AP:   0.2786  -------
# -------  Class: dog              AP:   0.3100  -------
# -------  Class: horse            AP:   0.4704  -------
# -------  Class: motorbike        AP:   0.4048  -------
# -------  Class: person           AP:   0.7534  -------
# -------  Class: pottedplant      AP:   0.1613  -------
# -------  Class: sheep            AP:   0.1669  -------
# -------  Class: sofa             AP:   0.2711  -------
# -------  Class: train            AP:   0.3699  -------
# -------  Class: tvmonitor        AP:   0.2903  -------
# mAP: 0.3318
# Avg loss: 0.18622555285692216
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 30 is 0.33182253427116426
# Starting epoch number 31
# Loss for Training on Epoch 31 is 0.1734486073255539
# Starting epoch number 32
# Loss for Training on Epoch 32 is 0.17440509796142578
# Starting epoch number 33
# Loss for Training on Epoch 33 is 0.1760101169347763
# Starting epoch number 34
# Loss for Training on Epoch 34 is 0.17179076373577118
# Starting epoch number 35
# Loss for Training on Epoch 35 is 0.17091496288776398
# -------  Class: aeroplane        AP:   0.4769  -------
# -------  Class: bicycle          AP:   0.2634  -------
# -------  Class: bird             AP:   0.2534  -------
# -------  Class: boat             AP:   0.3843  -------
# -------  Class: bottle           AP:   0.1512  -------
# -------  Class: bus              AP:   0.2047  -------
# -------  Class: car              AP:   0.5359  -------
# -------  Class: cat              AP:   0.3911  -------
# -------  Class: chair            AP:   0.4452  -------
# -------  Class: cow              AP:   0.1351  -------
# -------  Class: diningtable      AP:   0.3226  -------
# -------  Class: dog              AP:   0.3053  -------
# -------  Class: horse            AP:   0.4868  -------
# -------  Class: motorbike        AP:   0.4672  -------
# -------  Class: person           AP:   0.7667  -------
# -------  Class: pottedplant      AP:   0.1611  -------
# -------  Class: sheep            AP:   0.1797  -------
# -------  Class: sofa             AP:   0.2921  -------
# -------  Class: train            AP:   0.3700  -------
# -------  Class: tvmonitor        AP:   0.2593  -------
# mAP: 0.3426
# Avg loss: 0.18954911082983017
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 35 is 0.3426081664967035
# Starting epoch number 36
# Loss for Training on Epoch 36 is 0.16928210854530334
# Starting epoch number 37
# Loss for Training on Epoch 37 is 0.17059753835201263
# Starting epoch number 38
# Loss for Training on Epoch 38 is 0.16999351978302002
# Starting epoch number 39
# Loss for Training on Epoch 39 is 0.1651936024427414
# Starting epoch number 40
# Loss for Training on Epoch 40 is 0.16494683921337128
# -------  Class: aeroplane        AP:   0.5638  -------
# -------  Class: bicycle          AP:   0.3242  -------
# -------  Class: bird             AP:   0.1905  -------
# -------  Class: boat             AP:   0.3823  -------
# -------  Class: bottle           AP:   0.1733  -------
# -------  Class: bus              AP:   0.2641  -------
# -------  Class: car              AP:   0.5640  -------
# -------  Class: cat              AP:   0.4013  -------
# -------  Class: chair            AP:   0.4249  -------
# -------  Class: cow              AP:   0.1368  -------
# -------  Class: diningtable      AP:   0.3409  -------
# -------  Class: dog              AP:   0.3043  -------
# -------  Class: horse            AP:   0.5128  -------
# -------  Class: motorbike        AP:   0.3433  -------
# -------  Class: person           AP:   0.7632  -------
# -------  Class: pottedplant      AP:   0.1722  -------
# -------  Class: sheep            AP:   0.1794  -------
# -------  Class: sofa             AP:   0.2915  -------
# -------  Class: train            AP:   0.4184  -------
# -------  Class: tvmonitor        AP:   0.2740  -------
# mAP: 0.3513
# Avg loss: 0.18958738557994365
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 40 is 0.3512511991420838
# Starting epoch number 41
# Loss for Training on Epoch 41 is 0.16632942855358124
# Starting epoch number 42
# Loss for Training on Epoch 42 is 0.16630485653877258
# Starting epoch number 43
# Loss for Training on Epoch 43 is 0.16371369361877441
# Starting epoch number 44
# Loss for Training on Epoch 44 is 0.16211162507534027
# Starting epoch number 45
# Loss for Training on Epoch 45 is 0.16033317148685455
# -------  Class: aeroplane        AP:   0.5624  -------
# -------  Class: bicycle          AP:   0.3390  -------
# -------  Class: bird             AP:   0.2857  -------
# -------  Class: boat             AP:   0.4298  -------
# -------  Class: bottle           AP:   0.1521  -------
# -------  Class: bus              AP:   0.2522  -------
# -------  Class: car              AP:   0.5748  -------
# -------  Class: cat              AP:   0.3709  -------
# -------  Class: chair            AP:   0.4271  -------
# -------  Class: cow              AP:   0.1366  -------
# -------  Class: diningtable      AP:   0.2910  -------
# -------  Class: dog              AP:   0.3084  -------
# -------  Class: horse            AP:   0.5397  -------
# -------  Class: motorbike        AP:   0.3921  -------
# -------  Class: person           AP:   0.7734  -------
# -------  Class: pottedplant      AP:   0.1562  -------
# -------  Class: sheep            AP:   0.2193  -------
# -------  Class: sofa             AP:   0.2945  -------
# -------  Class: train            AP:   0.4982  -------
# -------  Class: tvmonitor        AP:   0.2600  -------
# mAP: 0.3632
# Avg loss: 0.1877938598394394
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 45 is 0.36318309507494834
# Starting epoch number 46
# Loss for Training on Epoch 46 is 0.15927822887897491
# Starting epoch number 47
# Loss for Training on Epoch 47 is 0.16080455482006073
# Starting epoch number 48
# Loss for Training on Epoch 48 is 0.16038428246974945
# Starting epoch number 49
# Loss for Training on Epoch 49 is 0.1561485379934311
# Starting epoch number 50
# Loss for Training on Epoch 50 is 0.15684671700000763
# -------  Class: aeroplane        AP:   0.5793  -------
# -------  Class: bicycle          AP:   0.3404  -------
# -------  Class: bird             AP:   0.2988  -------
# -------  Class: boat             AP:   0.4571  -------
# -------  Class: bottle           AP:   0.1541  -------
# -------  Class: bus              AP:   0.2897  -------
# -------  Class: car              AP:   0.5900  -------
# -------  Class: cat              AP:   0.3810  -------
# -------  Class: chair            AP:   0.4253  -------
# -------  Class: cow              AP:   0.1367  -------
# -------  Class: diningtable      AP:   0.3053  -------
# -------  Class: dog              AP:   0.3053  -------
# -------  Class: horse            AP:   0.5455  -------
# -------  Class: motorbike        AP:   0.4205  -------
# -------  Class: person           AP:   0.7812  -------
# -------  Class: pottedplant      AP:   0.1659  -------
# -------  Class: sheep            AP:   0.2077  -------
# -------  Class: sofa             AP:   0.2894  -------
# -------  Class: train            AP:   0.5197  -------
# -------  Class: tvmonitor        AP:   0.2932  -------
# mAP: 0.3743
# Avg loss: 0.17975731771439313
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 50 is 0.3743001780618263
# Starting epoch number 51
# Loss for Training on Epoch 51 is 0.15844345092773438
# Starting epoch number 52
# Loss for Training on Epoch 52 is 0.15580527484416962
# Starting epoch number 53
# Loss for Training on Epoch 53 is 0.1584347039461136
# Starting epoch number 54
# Loss for Training on Epoch 54 is 0.1572907567024231
# Starting epoch number 55
# Loss for Training on Epoch 55 is 0.1535053253173828
# -------  Class: aeroplane        AP:   0.5384  -------
# -------  Class: bicycle          AP:   0.3829  -------
# -------  Class: bird             AP:   0.2774  -------
# -------  Class: boat             AP:   0.4215  -------
# -------  Class: bottle           AP:   0.1693  -------
# -------  Class: bus              AP:   0.2794  -------
# -------  Class: car              AP:   0.5563  -------
# -------  Class: cat              AP:   0.3825  -------
# -------  Class: chair            AP:   0.4501  -------
# -------  Class: cow              AP:   0.1436  -------
# -------  Class: diningtable      AP:   0.3283  -------
# -------  Class: dog              AP:   0.3073  -------
# -------  Class: horse            AP:   0.5405  -------
# -------  Class: motorbike        AP:   0.4048  -------
# -------  Class: person           AP:   0.7780  -------
# -------  Class: pottedplant      AP:   0.1989  -------
# -------  Class: sheep            AP:   0.2135  -------
# -------  Class: sofa             AP:   0.3142  -------
# -------  Class: train            AP:   0.4688  -------
# -------  Class: tvmonitor        AP:   0.3025  -------
# mAP: 0.3729
# Avg loss: 0.18252324387431146
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 55 is 0.37290631493829385
# Starting epoch number 56
# Loss for Training on Epoch 56 is 0.15420500934123993
# Starting epoch number 57
# Loss for Training on Epoch 57 is 0.15660755336284637
# Starting epoch number 58
# Loss for Training on Epoch 58 is 0.15426772832870483
# Starting epoch number 59
# Loss for Training on Epoch 59 is 0.1528778076171875
# Starting epoch number 60
# Loss for Training on Epoch 60 is 0.15147940814495087
# -------  Class: aeroplane        AP:   0.5713  -------
# -------  Class: bicycle          AP:   0.3859  -------
# -------  Class: bird             AP:   0.2971  -------
# -------  Class: boat             AP:   0.4488  -------
# -------  Class: bottle           AP:   0.1548  -------
# -------  Class: bus              AP:   0.3352  -------
# -------  Class: car              AP:   0.6009  -------
# -------  Class: cat              AP:   0.3993  -------
# -------  Class: chair            AP:   0.4515  -------
# -------  Class: cow              AP:   0.1462  -------
# -------  Class: diningtable      AP:   0.3204  -------
# -------  Class: dog              AP:   0.3261  -------
# -------  Class: horse            AP:   0.5451  -------
# -------  Class: motorbike        AP:   0.4477  -------
# -------  Class: person           AP:   0.7790  -------
# -------  Class: pottedplant      AP:   0.1934  -------
# -------  Class: sheep            AP:   0.1985  -------
# -------  Class: sofa             AP:   0.2993  -------
# -------  Class: train            AP:   0.5344  -------
# -------  Class: tvmonitor        AP:   0.3300  -------
# mAP: 0.3882
# Avg loss: 0.1752083223313093
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 60 is 0.3882447649668358
# Starting epoch number 61
# Loss for Training on Epoch 61 is 0.14641860127449036
# Starting epoch number 62
# Loss for Training on Epoch 62 is 0.1492438167333603
# Starting epoch number 63
# Loss for Training on Epoch 63 is 0.14673487842082977
# Starting epoch number 64
# Loss for Training on Epoch 64 is 0.14721442759037018
# Starting epoch number 65
# Loss for Training on Epoch 65 is 0.1459292471408844
# -------  Class: aeroplane        AP:   0.5904  -------
# -------  Class: bicycle          AP:   0.3872  -------
# -------  Class: bird             AP:   0.2885  -------
# -------  Class: boat             AP:   0.4305  -------
# -------  Class: bottle           AP:   0.1334  -------
# -------  Class: bus              AP:   0.2610  -------
# -------  Class: car              AP:   0.6077  -------
# -------  Class: cat              AP:   0.3920  -------
# -------  Class: chair            AP:   0.4333  -------
# -------  Class: cow              AP:   0.1457  -------
# -------  Class: diningtable      AP:   0.2976  -------
# -------  Class: dog              AP:   0.3144  -------
# -------  Class: horse            AP:   0.5352  -------
# -------  Class: motorbike        AP:   0.3416  -------
# -------  Class: person           AP:   0.7674  -------
# -------  Class: pottedplant      AP:   0.1864  -------
# -------  Class: sheep            AP:   0.2245  -------
# -------  Class: sofa             AP:   0.3224  -------
# -------  Class: train            AP:   0.5223  -------
# -------  Class: tvmonitor        AP:   0.2861  -------
# mAP: 0.3734
# Avg loss: 0.1894299317151308
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 65 is 0.37338076658604497
# Starting epoch number 66
# Loss for Training on Epoch 66 is 0.14221803843975067
# Starting epoch number 67
# Loss for Training on Epoch 67 is 0.1462029218673706
# Starting epoch number 68
# Loss for Training on Epoch 68 is 0.14516060054302216
# Starting epoch number 69
# Loss for Training on Epoch 69 is 0.14748810231685638
# Starting epoch number 70
# Loss for Training on Epoch 70 is 0.14750869572162628
# -------  Class: aeroplane        AP:   0.5947  -------
# -------  Class: bicycle          AP:   0.3077  -------
# -------  Class: bird             AP:   0.3228  -------
# -------  Class: boat             AP:   0.4548  -------
# -------  Class: bottle           AP:   0.1617  -------
# -------  Class: bus              AP:   0.2606  -------
# -------  Class: car              AP:   0.5737  -------
# -------  Class: cat              AP:   0.3808  -------
# -------  Class: chair            AP:   0.4535  -------
# -------  Class: cow              AP:   0.1635  -------
# -------  Class: diningtable      AP:   0.3266  -------
# -------  Class: dog              AP:   0.3353  -------
# -------  Class: horse            AP:   0.5595  -------
# -------  Class: motorbike        AP:   0.4422  -------
# -------  Class: person           AP:   0.7857  -------
# -------  Class: pottedplant      AP:   0.2055  -------
# -------  Class: sheep            AP:   0.2167  -------
# -------  Class: sofa             AP:   0.2574  -------
# -------  Class: train            AP:   0.5280  -------
# -------  Class: tvmonitor        AP:   0.3104  -------
# mAP: 0.3821
# Avg loss: 0.18133604452013968
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 70 is 0.382056460404401
# Starting epoch number 71
# Loss for Training on Epoch 71 is 0.1453077644109726
# Starting epoch number 72
# Loss for Training on Epoch 72 is 0.14488251507282257
# Starting epoch number 73
# Loss for Training on Epoch 73 is 0.1396888792514801
# Starting epoch number 74
# Loss for Training on Epoch 74 is 0.14074914157390594
# Starting epoch number 75
# Loss for Training on Epoch 75 is 0.1422157734632492
# -------  Class: aeroplane        AP:   0.6149  -------
# -------  Class: bicycle          AP:   0.3064  -------
# -------  Class: bird             AP:   0.2746  -------
# -------  Class: boat             AP:   0.4157  -------
# -------  Class: bottle           AP:   0.1383  -------
# -------  Class: bus              AP:   0.2994  -------
# -------  Class: car              AP:   0.5862  -------
# -------  Class: cat              AP:   0.3772  -------
# -------  Class: chair            AP:   0.4535  -------
# -------  Class: cow              AP:   0.1548  -------
# -------  Class: diningtable      AP:   0.3041  -------
# -------  Class: dog              AP:   0.2518  -------
# -------  Class: horse            AP:   0.5341  -------
# -------  Class: motorbike        AP:   0.3821  -------
# -------  Class: person           AP:   0.7757  -------
# -------  Class: pottedplant      AP:   0.2164  -------
# -------  Class: sheep            AP:   0.2078  -------
# -------  Class: sofa             AP:   0.2750  -------
# -------  Class: train            AP:   0.4887  -------
# -------  Class: tvmonitor        AP:   0.3120  -------
# mAP: 0.3684
# Avg loss: 0.18944763951003551
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 75 is 0.36843646088111853
# Starting epoch number 76
# Loss for Training on Epoch 76 is 0.13983705639839172
# Starting epoch number 77
# Loss for Training on Epoch 77 is 0.13616998493671417
# Starting epoch number 78
# Loss for Training on Epoch 78 is 0.13437671959400177
# Starting epoch number 79
# Loss for Training on Epoch 79 is 0.13523225486278534
# Starting epoch number 80
# Loss for Training on Epoch 80 is 0.13338366150856018
# -------  Class: aeroplane        AP:   0.5990  -------
# -------  Class: bicycle          AP:   0.3593  -------
# -------  Class: bird             AP:   0.3132  -------
# -------  Class: boat             AP:   0.4799  -------
# -------  Class: bottle           AP:   0.1651  -------
# -------  Class: bus              AP:   0.3305  -------
# -------  Class: car              AP:   0.5772  -------
# -------  Class: cat              AP:   0.4171  -------
# -------  Class: chair            AP:   0.4596  -------
# -------  Class: cow              AP:   0.1632  -------
# -------  Class: diningtable      AP:   0.3434  -------
# -------  Class: dog              AP:   0.2998  -------
# -------  Class: horse            AP:   0.5306  -------
# -------  Class: motorbike        AP:   0.4905  -------
# -------  Class: person           AP:   0.7938  -------
# -------  Class: pottedplant      AP:   0.2125  -------
# -------  Class: sheep            AP:   0.2426  -------
# -------  Class: sofa             AP:   0.3258  -------
# -------  Class: train            AP:   0.5105  -------
# -------  Class: tvmonitor        AP:   0.3264  -------
# mAP: 0.3970
# Avg loss: 0.18592212051153184
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 80 is 0.396996326931344
# Starting epoch number 81
# Loss for Training on Epoch 81 is 0.13381138443946838
# Starting epoch number 82
# Loss for Training on Epoch 82 is 0.1372210830450058
# Starting epoch number 83
# Loss for Training on Epoch 83 is 0.13591952621936798
# Starting epoch number 84
# Loss for Training on Epoch 84 is 0.13267317414283752
# Starting epoch number 85
# Loss for Training on Epoch 85 is 0.13189087808132172
# -------  Class: aeroplane        AP:   0.6155  -------
# -------  Class: bicycle          AP:   0.3162  -------
# -------  Class: bird             AP:   0.3215  -------
# -------  Class: boat             AP:   0.4193  -------
# -------  Class: bottle           AP:   0.1605  -------
# -------  Class: bus              AP:   0.3213  -------
# -------  Class: car              AP:   0.6128  -------
# -------  Class: cat              AP:   0.4079  -------
# -------  Class: chair            AP:   0.4700  -------
# -------  Class: cow              AP:   0.1712  -------
# -------  Class: diningtable      AP:   0.3150  -------
# -------  Class: dog              AP:   0.3294  -------
# -------  Class: horse            AP:   0.5641  -------
# -------  Class: motorbike        AP:   0.5139  -------
# -------  Class: person           AP:   0.7851  -------
# -------  Class: pottedplant      AP:   0.1615  -------
# -------  Class: sheep            AP:   0.2504  -------
# -------  Class: sofa             AP:   0.2922  -------
# -------  Class: train            AP:   0.5296  -------
# -------  Class: tvmonitor        AP:   0.3031  -------
# mAP: 0.3930
# Avg loss: 0.19302553907036782
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 85 is 0.39302861668247907
# Starting epoch number 86
# Loss for Training on Epoch 86 is 0.12960384786128998
# Starting epoch number 87
# Loss for Training on Epoch 87 is 0.12975315749645233
# Starting epoch number 88
# Loss for Training on Epoch 88 is 0.13311247527599335
# Starting epoch number 89
# Loss for Training on Epoch 89 is 0.13239383697509766
# Starting epoch number 90
# Loss for Training on Epoch 90 is 0.13324934244155884
# -------  Class: aeroplane        AP:   0.6086  -------
# -------  Class: bicycle          AP:   0.4325  -------
# -------  Class: bird             AP:   0.3297  -------
# -------  Class: boat             AP:   0.4293  -------
# -------  Class: bottle           AP:   0.1832  -------
# -------  Class: bus              AP:   0.2950  -------
# -------  Class: car              AP:   0.5945  -------
# -------  Class: cat              AP:   0.4088  -------
# -------  Class: chair            AP:   0.4793  -------
# -------  Class: cow              AP:   0.1750  -------
# -------  Class: diningtable      AP:   0.3371  -------
# -------  Class: dog              AP:   0.3019  -------
# -------  Class: horse            AP:   0.5422  -------
# -------  Class: motorbike        AP:   0.5286  -------
# -------  Class: person           AP:   0.7851  -------
# -------  Class: pottedplant      AP:   0.1704  -------
# -------  Class: sheep            AP:   0.2387  -------
# -------  Class: sofa             AP:   0.2717  -------
# -------  Class: train            AP:   0.4674  -------
# -------  Class: tvmonitor        AP:   0.3114  -------
# mAP: 0.3945
# Avg loss: 0.1843546975404024
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 90 is 0.3945323376467953
# Starting epoch number 91
# Loss for Training on Epoch 91 is 0.13327248394489288
# Starting epoch number 92
# Loss for Training on Epoch 92 is 0.1300264596939087
# Starting epoch number 93
# Loss for Training on Epoch 93 is 0.13290753960609436
# Starting epoch number 94
# Loss for Training on Epoch 94 is 0.1313265562057495
# Starting epoch number 95
# Loss for Training on Epoch 95 is 0.13012312352657318
# -------  Class: aeroplane        AP:   0.6309  -------
# -------  Class: bicycle          AP:   0.4659  -------
# -------  Class: bird             AP:   0.3268  -------
# -------  Class: boat             AP:   0.4572  -------
# -------  Class: bottle           AP:   0.1429  -------
# -------  Class: bus              AP:   0.3305  -------
# -------  Class: car              AP:   0.5921  -------
# -------  Class: cat              AP:   0.3966  -------
# -------  Class: chair            AP:   0.4641  -------
# -------  Class: cow              AP:   0.1530  -------
# -------  Class: diningtable      AP:   0.3161  -------
# -------  Class: dog              AP:   0.3248  -------
# -------  Class: horse            AP:   0.5535  -------
# -------  Class: motorbike        AP:   0.4900  -------
# -------  Class: person           AP:   0.7795  -------
# -------  Class: pottedplant      AP:   0.2016  -------
# -------  Class: sheep            AP:   0.2035  -------
# -------  Class: sofa             AP:   0.2953  -------
# -------  Class: train            AP:   0.5085  -------
# -------  Class: tvmonitor        AP:   0.3048  -------
# mAP: 0.3969
# Avg loss: 0.1934341661632061
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 95 is 0.3968877015816489
# Starting epoch number 96
# Loss for Training on Epoch 96 is 0.12584009766578674
# Starting epoch number 97
# Loss for Training on Epoch 97 is 0.12420989573001862
# Starting epoch number 98
# Loss for Training on Epoch 98 is 0.12643752992153168
# Starting epoch number 99
# Loss for Training on Epoch 99 is 0.12359156459569931
# Starting epoch number 100
# Loss for Training on Epoch 100 is 0.12027640640735626
# -------  Class: aeroplane        AP:   0.6160  -------
# -------  Class: bicycle          AP:   0.3921  -------
# -------  Class: bird             AP:   0.3165  -------
# -------  Class: boat             AP:   0.4481  -------
# -------  Class: bottle           AP:   0.1406  -------
# -------  Class: bus              AP:   0.3070  -------
# -------  Class: car              AP:   0.6072  -------
# -------  Class: cat              AP:   0.4003  -------
# -------  Class: chair            AP:   0.4630  -------
# -------  Class: cow              AP:   0.1518  -------
# -------  Class: diningtable      AP:   0.3446  -------
# -------  Class: dog              AP:   0.2905  -------
# -------  Class: horse            AP:   0.5599  -------
# -------  Class: motorbike        AP:   0.4950  -------
# -------  Class: person           AP:   0.7823  -------
# -------  Class: pottedplant      AP:   0.2132  -------
# -------  Class: sheep            AP:   0.2123  -------
# -------  Class: sofa             AP:   0.2635  -------
# -------  Class: train            AP:   0.5959  -------
# -------  Class: tvmonitor        AP:   0.3029  -------
# mAP: 0.3951
# Avg loss: 0.192189559340477
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 100 is 0.3951283589257796

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print(mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.5895  -------
# -------  Class: bicycle          AP:   0.3813  -------
# -------  Class: bird             AP:   0.2799  -------
# -------  Class: boat             AP:   0.3954  -------
# -------  Class: bottle           AP:   0.1708  -------
# -------  Class: bus              AP:   0.3076  -------
# -------  Class: car              AP:   0.6071  -------
# -------  Class: cat              AP:   0.3855  -------
# -------  Class: chair            AP:   0.4199  -------
# -------  Class: cow              AP:   0.2035  -------
# -------  Class: diningtable      AP:   0.2596  -------
# -------  Class: dog              AP:   0.3084  -------
# -------  Class: horse            AP:   0.6558  -------
# -------  Class: motorbike        AP:   0.4478  -------
# -------  Class: person           AP:   0.7879  -------
# -------  Class: pottedplant      AP:   0.2095  -------
# -------  Class: sheep            AP:   0.2361  -------
# -------  Class: sofa             AP:   0.2797  -------
# -------  Class: train            AP:   0.5617  -------
# -------  Class: tvmonitor        AP:   0.3548  -------
# mAP: 0.3921
# Avg loss: 0.1893877211289528
# 0.3920762553225598

# %%
torch.save(classifier.state_dict(), './voc_my_best_classifier.pth')
output_submission_csv('my_solution.csv', test_aps)
